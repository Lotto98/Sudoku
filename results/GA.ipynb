# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("GA.csv")
dataset.dropna(axis = 0, how = 'all',inplace=True)
dataset.reset_index(drop=True,inplace=True)
dataset
# Out:
#        name difficulty  full cells  exec time  restarts  total generations
# 0     easy1       easy        35.0    47.1244       1.0               47.0
# 1     easy2       easy        37.0    36.1862       1.0               25.0
# 2     easy3       easy        38.0    40.6885       1.0               29.0
# 3     easy4       easy        40.0    41.8533       1.0               30.0
# 4     easy5       easy        41.0    29.6387       1.0               20.0
# 5     easy6       easy        35.0    54.0527       1.0               40.0
# 6   normal1     normal        29.0   198.5801       2.0              153.0
# 7   normal2     normal        30.0   477.2946       5.0              370.0
# 8   normal3     normal        32.0   573.0070       6.0              448.0
# 9   normal4     normal        32.0   147.4415       2.0              112.0
# 10  normal5     normal        30.0   666.5298       7.0              514.0
# ...

# %%
print(dataset["exec time"].mean())
print(dataset["exec time"].std())

print(dataset["restarts"].mean())
print(dataset["restarts"].std())

print(dataset["total generations"].mean())
print(dataset["total generations"].std())
# Out:
# 1336.09455
# 1919.1785796484032
# 10.409090909090908
# 13.069991404919719
# 926.4090909090909
# 1368.0832145078682

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(dataset.corr(), fignum=f.number)
plt.xticks(range(dataset.select_dtypes(['number']).shape[1]), dataset.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(dataset.select_dtypes(['number']).shape[1]), dataset.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)

for (i, j), z in np.ndenumerate(dataset.corr()):
    plt.text(j, i, '{:0.6f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
# Out:
# /tmp/ipykernel_36823/3887813013.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(dataset.corr(), fignum=f.number)
# /tmp/ipykernel_36823/3887813013.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   for (i, j), z in np.ndenumerate(dataset.corr()):

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_36823/1221638645.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dataset.corr()
# <style type="text/css">
# #T_a8983_row0_col0, #T_a8983_row1_col1, #T_a8983_row2_col2, #T_a8983_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a8983_row0_col1, #T_a8983_row0_col2, #T_a8983_row0_col3, #T_a8983_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a8983_row1_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a8983_row1_col2, #T_a8983_row2_col1, #T_a8983_row2_col3, #T_a8983_row3_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_a8983_row1_col3, #T_a8983_row3_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_a8983_row3_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# </style>
# ...

# %%
dataset.boxplot(by ='difficulty', column =['exec time'], grid = False)
# Out:
# <AxesSubplot: title={'center': 'exec time'}, xlabel='difficulty'>

# %%
dataset.boxplot(by ='difficulty', column =['total generations'], grid = False)
# Out:
# <AxesSubplot: title={'center': 'total generations'}, xlabel='difficulty'>

# %%
f = plt.figure(figsize=(19, 15))
plt.scatter(dataset["exec time"],dataset["restarts"])

# %%
f = plt.figure(figsize=(19, 15))
plt.scatter(dataset["exec time"],dataset["total generations"])
