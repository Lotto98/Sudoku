# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("CPandBT.csv")
dataset.dropna(axis = 0, how = 'all',inplace=True)
dataset.reset_index(drop=True,inplace=True)
dataset.drop("tentative assignments",axis=1,inplace=True)
dataset
# Out:
#        name difficulty  full cells  exec time  restored nodes
# 0     easy1       easy        35.0     0.0015             0.0
# 1     easy2       easy        37.0     0.0015             0.0
# 2     easy3       easy        38.0     0.0016             0.0
# 3     easy4       easy        40.0     0.0015             0.0
# 4     easy5       easy        41.0     0.0015             0.0
# 5     easy6       easy        35.0     0.0017             0.0
# 6   normal1     normal        29.0     0.0021            11.0
# 7   normal2     normal        30.0     0.0016             0.0
# 8   normal3     normal        32.0     0.0018             3.0
# 9   normal4     normal        32.0     0.0017             3.0
# 10  normal5     normal        30.0     0.0130           316.0
# 11  medium1     medium        29.0     0.0035            75.0
# 12  medium2     medium        25.0     0.0033             5.0
# 13  medium3     medium        25.0     0.0018             2.0
# 14  medium4     medium        28.0     0.0032            56.0
# 15  medium5     medium        25.0     0.0017             0.0
# 16    hard1       hard        23.0     0.0846          3204.0
# 17    hard2       hard        25.0     0.0024            29.0
# 18    hard3       hard        23.0     0.0017             2.0
# 19    hard4       hard        22.0     0.0022             0.0
# 20    hard5       hard        21.0     0.0018             0.0
# 21    hard6       hard        21.0     0.0594          1313.0

# %%
print(dataset["exec time"].mean())
print(dataset["exec time"].std())

print(dataset["full cells"].mean())
print(dataset["full cells"].std())

print(dataset["restored nodes"].mean())
print(dataset["restored nodes"].std())

#print(dataset["tentative assignments"].mean())
#print(dataset["tentative assignments"].std())
# Out:
# 0.008868181818181818
# 0.020939968307695043
# 29.363636363636363
# 6.222428361870848
# 228.13636363636363
# 722.2385370007643

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(dataset.corr(), fignum=f.number)
plt.xticks(range(dataset.select_dtypes(['number']).shape[1]), dataset.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(dataset.select_dtypes(['number']).shape[1]), dataset.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)

for (i, j), z in np.ndenumerate(dataset.corr()):
    plt.text(j, i, '{:0.6f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
# Out:
# /tmp/ipykernel_7536/3887813013.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(dataset.corr(), fignum=f.number)
# /tmp/ipykernel_7536/3887813013.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   for (i, j), z in np.ndenumerate(dataset.corr()):

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_7536/1221638645.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dataset.corr()
# <style type="text/css">
# #T_5969b_row0_col0, #T_5969b_row1_col1, #T_5969b_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5969b_row0_col1, #T_5969b_row0_col2, #T_5969b_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5969b_row1_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_5969b_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5969b_row2_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5969b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5969b_level0_col0" class="col_heading level0 col0" >full cells</th>
#       <th id="T_5969b_level0_col1" class="col_heading level0 col1" >exec time</th>
#       <th id="T_5969b_level0_col2" class="col_heading level0 col2" >restored nodes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5969b_level0_row0" class="row_heading level0 row0" >full cells</th>
#       <td id="T_5969b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5969b_row0_col1" class="data row0 col1" >-0.375896</td>
#       <td id="T_5969b_row0_col2" class="data row0 col2" >-0.333042</td>
#     </tr>
#     <tr>
#       <th id="T_5969b_level0_row1" class="row_heading level0 row1" >exec time</th>
#       <td id="T_5969b_row1_col0" class="data row1 col0" >-0.375896</td>
#       <td id="T_5969b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5969b_row1_col2" class="data row1 col2" >0.973617</td>
#     </tr>
#     <tr>
#       <th id="T_5969b_level0_row2" class="row_heading level0 row2" >restored nodes</th>
#       <td id="T_5969b_row2_col0" class="data row2 col0" >-0.333042</td>
#       <td id="T_5969b_row2_col1" class="data row2 col1" >0.973617</td>
#       <td id="T_5969b_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
dataset.boxplot(by ='difficulty', column =['exec time'], grid = False)
# Out:
# <AxesSubplot: title={'center': 'exec time'}, xlabel='difficulty'>

# %%
dataset.boxplot(by ='difficulty', column =['restored cells'], grid = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [109], line 1
# ----> 1 dataset.boxplot(by ='difficulty', column =['restored cells'], grid = False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:516, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     499 @Substitution(backend=_backend_doc)
#     500 @Appender(_boxplot_doc)
#     501 def boxplot_frame(
#    (...)
#     513     **kwargs,
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#     519         by=by,
#     520         ax=ax,
#     521         fontsize=fontsize,
#     522         rot=rot,
#     523         grid=grid,
#     524         figsize=figsize,
#     525         layout=layout,
#     526         return_type=return_type,
#     527         **kwargs,
#     528     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/boxplot.py:458, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     443 def boxplot_frame(
#     444     self,
#     445     column=None,
#    (...)
#     454     **kwds,
#     455 ):
#     456     import matplotlib.pyplot as plt
# --> 458     ax = boxplot(
#     459         self,
#     460         column=column,
#     461         by=by,
#     462         ax=ax,
#     463         fontsize=fontsize,
#     464         grid=grid,
#     465         rot=rot,
#     466         figsize=figsize,
#     467         layout=layout,
#     468         return_type=return_type,
#     469         **kwds,
#     470     )
#     471     plt.draw_if_interactive()
#     472     return ax
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/boxplot.py:404, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     399         columns = [column]
#     401 if by is not None:
#     402     # Prefer array return type for 2-D plots to match the subplot layout
#     403     # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 404     result = _grouped_plot_by_column(
#     405         plot_group,
#     406         data,
#     407         columns=columns,
#     408         by=by,
#     409         grid=grid,
#     410         figsize=figsize,
#     411         ax=ax,
#     412         layout=layout,
#     413         return_type=return_type,
#     414         **kwds,
#     415     )
#     416 else:
#     417     if return_type is None:
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/boxplot.py:272, in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     270 for i, col in enumerate(columns):
#     271     ax = _axes[i]
# --> 272     gp_col = grouped[col]
#     273     keys, values = zip(*gp_col)
#     274     re_plotf = plotf(keys, values, ax, xlabel=xlabel, ylabel=ylabel, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1415, in DataFrameGroupBy.__getitem__(self, key)
#    1406 if isinstance(key, tuple) and len(key) > 1:
#    1407     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1408     # valid syntax, so don't raise warning
#    1409     warnings.warn(
#    1410         "Indexing with multiple keys (implicitly converted to a tuple "
#    1411         "of keys) will be deprecated, use a list instead.",
#    1412         FutureWarning,
#    1413         stacklevel=find_stack_level(),
#    1414     )
# -> 1415 return super().__getitem__(key)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
#     247     if key not in self.obj:
# --> 248         raise KeyError(f"Column not found: {key}")
#     249     subset = self.obj[key]
#     250     ndim = subset.ndim
#
# KeyError: 'Column not found: restored cells'

# %%
f = plt.figure(figsize=(19, 15))
plt.scatter(dataset["exec time"],dataset["full cells"])

# %%
f = plt.figure(figsize=(19, 15))
plt.scatter(dataset["exec time"],dataset["restored cells"])
